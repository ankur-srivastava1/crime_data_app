# %%
import pandas as pd
import numpy as np
import datetime
from sodapy import Socrata

# %%
def get_crime_data(city = 'SFO',
                   start_time = datetime.date.today() - datetime.timedelta(days = 7),
                   end_time = datetime.date.today()):
    
    if city == 'SFO':
        client_name = 'data.sfgov.org'
        api_endpoint = 'wg3w-h783'
        relevant_cols = 'analysis_neighborhood,incident_category,incident_code,incident_description,latitude,longitude,point,police_district,incident_datetime,report_datetime,report_type_code,report_type_description,resolution,supervisor_district'
        date_col = 'report_datetime'
    else:
        client_name = 'data.cityofchicago.org'
        api_endpoint = 'ijzp-q8t2'
        relevant_cols = 'arrest, beat, block,case_number,date,description,district,domestic,fbi_code,location_description,primary_type,ward'
        date_col = 'date'

    client = Socrata(client_name, None)
    
    where_query = date_col + ' between ' + "'"+str(start_time) + 'T00:00:00'+"'"+ ' and ' + "'"+str(end_time) + 'T00:00:00'+"'"
    
    results = client.get(dataset_identifier = api_endpoint, 
                     content_type = 'json',
                     where = where_query,
                     select = relevant_cols)
    # Convert to pandas DataFrame
    results_df = pd.DataFrame.from_records(results)

    return(results_df)

# %%
get_crime_data(city = 'SFO',
               start_time = '2019-01-01',
               end_time = '2019-01-10')
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#               analysis_neighborhood                         incident_category  \
# 0             Bayview Hunters Point                             Larceny Theft
# 1                               NaN                             Lost Property
# 2                    Bernal Heights                       Motor Vehicle Theft
# 3                           Mission                              Embezzlement
# 4                           Mission                                   Assault
# 5                               NaN                             Larceny Theft
# 6                               NaN                             Larceny Theft
# 7                   Sunset/Parkside                                   Assault
# 8                           Mission                                   Assault
# 9                        Tenderloin                                   Assault
# 10                              NaN                        Malicious Mischief
# 11                 Presidio Heights                       Other Miscellaneous
# 12            Bayview Hunters Point                             Larceny Theft
# 13                       Tenderloin                              Drug Offense
# 14                     Russian Hill                              Non-Criminal
# 15            Bayview Hunters Point                             Larceny Theft
# 16                      North Beach                                   Robbery
# 17                  South of Market                              Case Closure
# 18                          Mission                                   Assault
# 19            Bayview Hunters Point                                   Assault
# 20                         Seacliff                              Non-Criminal
# 21                     Russian Hill                             Larceny Theft
# 22                              NaN                             Lost Property
# 23                              NaN                         Recovered Vehicle
# 24                              NaN                             Lost Property
# 25                              NaN                             Larceny Theft
# 26                     Potrero Hill                            Missing Person
# 27                              NaN                         Recovered Vehicle
# 28                     Potrero Hill                                   Robbery
# 29                        Excelsior                        Disorderly Conduct
# ..                              ...                                       ...
# 970           Bayview Hunters Point                             Larceny Theft
# 971                    Russian Hill                             Larceny Theft
# 972                  Outer Richmond                             Larceny Theft
# 973                          Marina                             Lost Property
# 974                 South of Market                             Larceny Theft
# 975  Financial District/South Beach                             Lost Property
# 976  Financial District/South Beach                             Larceny Theft
# 977                      Tenderloin                                  Burglary
# 978                      Tenderloin                           Stolen Property
# 979                      Tenderloin                                   Warrant
# 980                    Hayes Valley                             Larceny Theft
# 981                     Mission Bay                                  Burglary
# 982                  Outer Richmond                              Non-Criminal
# 983                   Outer Mission                             Larceny Theft
# 984               Lone Mountain/USF                        Disorderly Conduct
# 985              West of Twin Peaks                                   Warrant
# 986                         Mission                             Larceny Theft
# 997         06372  2018-12-26T14:30:00.000
# 998         71013  2018-10-26T07:00:00.000
# 999         65010  2019-01-01T23:12:00.000
#
#                                   incident_description            latitude  \
# 0                    Theft, From Locked Vehicle, >$950   37.73686374466345
# 1                                        Lost Property                 NaN
# 2                                Vehicle, Stolen, Auto   37.73815553767246
# 3                            Embezzlement, Grand Theft     37.772343919036
# 4                                              Battery  37.765183133520345
# 5                  Theft, From Unlocked Vehicle, >$950                 NaN
# 6                    Theft, From Locked Vehicle, >$950                 NaN
# 7                                              Battery  37.763420291159434
# 8                                              Battery  37.763429272147256
# 9                                              Battery   37.78242041771279
# 10           Malicious Mischief, Vandalism to Property                 NaN
# 11        Driving While Under The Influence Of Alcohol   37.78508363438859
# 12                        Theft, Other Property, >$950   37.74252073319404
# 13                            Cocaine, Base/rock, Sale  37.785167213738916
# 14                                          Aided Case    37.8047903066652
# 15                     Theft, From Building, $200-$950  37.724693136232496
# 16             Robbery, Street or Public Place, W/ Gun   37.80489600962184
# 17                                        Case Closure    37.7751608100771
# 18                                             Battery  37.765958187824175
# 19       Battery, former Spouse or Dating Relationship  37.717173709492855
# 20                                     Found  Property   37.78511874382036
# 21                 Theft, From Unlocked Vehicle, >$950   37.80126734710793
# 22                                       Lost Property                 NaN
# 23                            Vehicle, Recovered, Auto                 NaN
# 24                                       Lost Property                 NaN
# 25                 Theft, From Unlocked Vehicle, >$950                 NaN
# 26                                        Found Person  37.754706578836675
# 27                            Vehicle, Recovered, Auto                 NaN
# 28                          Robbery,  ATM, Knife, Att.   37.75527014505354
# 29                                   Terrorist Threats    37.7263229218403
# ..                                                 ...                 ...
# 970                  Theft, From Locked Vehicle, >$950   37.72921143709946
# 971                  Theft, From Locked Vehicle, >$950   37.79733382877922
# 972            Theft, From Unlocked Vehicle, $200-$950   37.77831144810871
# 973                                      Lost Property   37.79921236567204
# 974                    Theft, From Building, $200-$950   37.77333262413091
# 975                                      Lost Property   37.78735926098589
# 976                    Theft, Other Property, $50-$200   37.78735926098589
# 977          Burglary, Apartment House, Unlawful Entry   37.78672974391054
# 978  Stolen Property, Possession with Knowledge, Re...   37.78423573864025
# 979                   Warrant Arrest, Local SF Warrant   37.78640961281089
# 980                       Theft, Other Property, >$950  37.775997142169274
# 981                    Burglary, Store, Forcible Entry   37.77403085060099
# 982                                    Found  Property   37.77704400153006
# 983                       Theft, Pickpocket, $200-$950   37.72072422316314
# 984                                  Terrorist Threats   37.78131458534108
# 985    Warrant Arrest, Enroute To Outside Jurisdiction  37.733801548310666
# 986                       Theft, Other Property, >$950   37.77034734336754
# 987                           Traffic Violation Arrest  37.785167213738916
# 988              Burglary, Other Bldg., Unlawful Entry  37.789829338038246
# 989                   Warrant Arrest, Local SF Warrant   37.78640961281089
# 990                     Violation of Restraining Order  37.732079051384794
# 991                           Traffic Violation Arrest   37.77311442180407
# 992                                            Runaway   37.72498829635846
# 993                            Mental Health Detention  37.727610075454194
# 994                        Vehicle, Stolen, Motorcycle   37.75723240847821
# 995                                      Missing Adult   37.77264947305175
# 996              Theft, From Locked Vehicle, $200-$950  37.716189203874436
# 979         Central  2019-01-09T05:10:00.000               IS
# 980        Northern  2019-01-09T14:59:00.000               II
# 981        Southern  2019-01-01T14:48:00.000               IS
# 982        Richmond  2019-01-06T13:25:00.000               II
# 983       Ingleside  2019-01-01T14:17:00.000               II
# 984        Richmond  2019-01-07T18:08:00.000               II
# 985       Ingleside  2019-01-03T14:40:00.000               II
# 986        Southern  2019-01-06T10:55:00.000               II
# 987      Tenderloin  2019-01-08T03:19:00.000               II
# 988         Central  2019-01-01T13:28:00.000               II
# 989         Central  2019-01-03T21:44:00.000               II
# 990         Bayview  2019-01-05T07:13:00.000               II
# 991        Richmond  2019-01-09T22:37:00.000               II
# 992         Mission  2019-01-05T15:43:00.000               II
# 993         Taraval  2019-01-01T08:53:00.000               II
# 994         Mission  2019-01-02T17:37:00.000               VI
# 995        Southern  2019-01-03T14:11:00.000               II
# 996       Ingleside  2019-01-04T08:25:00.000               II
# 997            Park  2019-01-06T12:47:00.000               II
# 998         Taraval  2019-01-02T15:41:00.000               VI
# 999         Mission  2019-01-01T23:13:00.000               II
#
#     report_type_description            resolution supervisor_district
# 0          Coplogic Initial        Open or Active                  10
# 1          Coplogic Initial        Open or Active                 NaN
# 2           Vehicle Initial        Open or Active                   9
# 3                   Initial        Open or Active                   6
# 4                   Initial        Open or Active                   9
# 5          Coplogic Initial        Open or Active                 NaN
# 6       Coplogic Supplement        Open or Active                 NaN
# 7                   Initial        Open or Active                   4
# 8                   Initial        Open or Active                   9
# 9                   Initial        Open or Active                   6
# 10         Coplogic Initial        Open or Active                 NaN
# 11                  Initial  Cite or Arrest Adult                   2
# 12         Coplogic Initial        Open or Active                  10
# 13                  Initial  Cite or Arrest Adult                   6
# 14                  Initial        Open or Active                   2
# 15                  Initial        Open or Active                  10
# 16                  Initial        Open or Active                   3
# 17                  Initial             Unfounded                   6
# 18                  Initial        Open or Active                  10
# 19                  Initial  Cite or Arrest Adult                  10
# 20                  Initial        Open or Active                   2
# 21      Coplogic Supplement        Open or Active                   3
# 22         Coplogic Initial        Open or Active                 NaN
# 23       Vehicle Supplement        Open or Active                 NaN
# 24         Coplogic Initial        Open or Active                 NaN
# 25         Coplogic Initial        Open or Active                 NaN
# 26                  Initial        Open or Active                  10
# 27       Vehicle Supplement        Open or Active                 NaN
# 28                  Initial        Open or Active                  10
# 29                  Initial        Open or Active                  11
# ..                      ...                   ...                 ...
# 970        Coplogic Initial        Open or Active                  10
# 971                 Initial        Open or Active                   3
# 972                 Initial        Open or Active                   1
# 973                 Initial        Open or Active                   2
# 974                 Initial        Open or Active                   6
# 975     Coplogic Supplement        Open or Active                   3
# 976      Initial Supplement        Open or Active                   3
# 977                 Initial        Open or Active                   6
# 978      Initial Supplement  Cite or Arrest Adult                   6
# 979      Initial Supplement  Cite or Arrest Adult                   3
# 980        Coplogic Initial        Open or Active                   5
# 981      Initial Supplement  Cite or Arrest Adult                   6
# 982                 Initial        Open or Active                   1
# 983                 Initial        Open or Active                  11
# 984                 Initial  Cite or Arrest Adult                   1
# 985                 Initial  Cite or Arrest Adult                   7
# 986        Coplogic Initial        Open or Active                   6
# 987                 Initial  Cite or Arrest Adult                   6
# 988                 Initial        Open or Active                   3
# 989                 Initial  Cite or Arrest Adult                   3
# 990                 Initial  Cite or Arrest Adult                  10
# 991                 Initial  Cite or Arrest Adult                   1
# 992                 Initial        Open or Active                  11
# 993                 Initial        Open or Active                   7
# 994         Vehicle Initial        Open or Active                   9
# 995                 Initial        Open or Active                   6
# 996                 Initial        Open or Active                  11
# 997        Coplogic Initial        Open or Active                 NaN
# 998         Vehicle Initial        Open or Active                   7
# 999                 Initial  Cite or Arrest Adult                   9
#
# [1000 rows x 14 columns]

# %%
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# # To get relevant columns for each data source

# %%
metadata = client.get_metadata(api_endpoint)

# %%
df = pd.DataFrame()
for x in metadata['columns']:
    if('description' in x):
        tmp_dict = {'col_name':[x['name']],'col_def':[x['description']]}
    else:
        tmp_dict = {'col_name':[x['name']],'col_def':['Not Available']}
    df = df.append(pd.DataFrame(tmp_dict),ignore_index=True)
df
# Out:
#                                               col_def  \
# 0                   Unique identifier for the record.
# 1   The Chicago Police Department RD Number (Recor...
# 2   Date when the incident occurred. this is somet...
# 3   The partially redacted address where the incid...
# 4   The Illinois Unifrom Crime Reporting code. Thi...
# 5           The primary description of the IUCR code.
# 6   The secondary description of the IUCR code, a ...
# 7   Description of the location where the incident...
# 8               Indicates whether an arrest was made.
# 9   Indicates whether the incident was domestic-re...
# 10  Indicates the beat where the incident occurred...
# 11  Indicates the police district where the incide...
# 12  The ward (City Council district) where the inc...
# 13  Indicates the community area where the inciden...
# 14  Indicates the crime classification as outlined...
# 15  The x coordinate of the location where the inc...
# 16  The y coordinate of the location where the inc...
# 17                        Year the incident occurred.
# 18         Date and time the record was last updated.
# 19  The latitude of the location where the inciden...
# 20  The longitude of the location where the incide...
# 21  The location where the incident occurred in a ...
# 22                                      Not Available
# 23                                      Not Available
# 24                                      Not Available
# 25                                      Not Available
# 26
# 27                                      Not Available
# 28                                      Not Available
# 29                                      Not Available
#
#                       col_name
# 0                           ID
# 1                  Case Number
# 2                         Date
# 3                        Block
# 4                         IUCR
# 5                 Primary Type
# 6                  Description
# 7         Location Description
# 8                       Arrest
# 9                     Domestic
# 10                        Beat
# 11                    District
# 12                        Ward
# 13              Community Area
# 14                    FBI Code
# 15                X Coordinate
# 16                Y Coordinate
# 17                        Year
# 18                  Updated On
# 19                    Latitude
# 20                   Longitude
# 21                    Location
# 22  Historical Wards 2003-2015
# 23                   Zip Codes
# 24             Community Areas
# 25               Census Tracts
# 26                       Wards
# 27      Boundaries - ZIP Codes
# 28            Police Districts
# 29                Police Beats

# %%
relevant_cols = 'arrest, beat, block,case_number,date,description,district,domestic,fbi_code,location_description,primary_type,ward'

# %%
date_col = 'date'
start_time = datetime.date.today() - datetime.timedelta(days = 7)
end_time = datetime.date.today()
where_query = date_col + ' between ' + "'"+str(start_time) + 'T00:00:00'+"'"+ ' and ' + "'"+str(end_time) + 'T00:00:00'+"'"
where_query
# Out:
# "date between '2019-06-03T00:00:00' and '2019-06-10T00:00:00'"

# %%
city = 'CHI'
client_name = 'data.cityofchicago.org'
api_endpoint = 'ijzp-q8t2'
client = Socrata(client_name, None)
results = client.get(dataset_identifier = api_endpoint, 
                     content_type = 'json',
                     where = "date between '2019-01-01T00:00:00' and '2019-06-10T00:00:00'",
                     select = relevant_cols
                     #limit = 100
                    )
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      arrest  beat                   block case_number  \
# 0     False  1654        102XX W ZEMKE RD    JC300604
# 1     False  0731     074XX S HARVARD AVE    JC256913
# 2     False  1654        102XX W ZEMKE RD    JC300596
# 3     False  0522        0000X W 115TH ST    JC294379
# 4     False  0524          116XX S ADA ST    JC286255
# 5     False  1831        004XX N STATE ST    JC100123
# 6     False  2223      092XX S NORMAL AVE    JC100085
# 7     False  0922   044XX S WASHTENAW AVE    JC100020
# 8     False  0725  063XX S MARSHFIELD AVE    JC100058
# 9     False  1833    008XX N MICHIGAN AVE    JC100745
# 10    False  2522  022XX N LEAMINGTON AVE    JC100934
# 11    False  1913      047XX N RACINE AVE    JC101115
# 12    False  2511     062XX W BELMONT AVE    JC101459
# 13    False  0412      083XX S YATES BLVD    JC104365
# 14    False  1831      002XX W ONTARIO ST    JC106702
# 15    False  0331     068XX S OGLESBY AVE    JC108820
# 16    False  1713      049XX N ALBANY AVE    JC109129
# 17    False  0221       045XX S EVANS AVE    JC112682
# 18    False  0324    072XX S EAST END AVE    JC116315
# 19    False  1522    0000X N LOCKWOOD AVE    JC123039
# 20    False  1813   016XX N CLEVELAND AVE    JC126701
# 21    False  1912   045XX N GREENVIEW AVE    JC137815
# 22    False  1011     012XX S KILDARE AVE    JC142283
# 23    False  1125   003XX S MAPLEWOOD AVE    JC144448
# 24    False  0422    080XX S EXCHANGE AVE    JC167775
# 25    False  0821       043XX S HOMAN AVE    JC170353
# 26    False  0833         038XX W 69TH ST    JC191123
# 27    False  2032      021XX W AINSLIE ST    JC192593
# 28    False  1931      028XX N PAULINA ST    JC207529
# 29    False  1913       045XX N BEACON ST    JC210380
# ..      ...   ...                     ...         ...
# 970   False  0433     134XX S BRANDON AVE    JC101364
# 971   False  0211   006XX E WOODLAND PARK    JC101382
# 972   False  1234       018XX S DAMEN AVE    JC101367
# 973   False  0611       080XX S HONORE ST    JC101370
# 974   False  2032      017XX W AINSLIE ST    JC101449
# 975   False  0414   077XX S RIDGELAND AVE    JC103363
# 976    True  0523        005XX W 127TH ST    JC101368
# 977   False  0121       006XX W MONROE ST    JC103349
# 978   False  0714      062XX S PAULINA ST    JC105600
# 979   False  1933     009XX W BELMONT AVE    JC101369
# 980   False  2413       061XX N HOYNE AVE    JC101372
# 981   False  1132     042XX W FILLMORE ST    JC101373
# 982   False  0823         032XX W 64TH ST    JC101417
# 983   False  2422     015XX W JUNEWAY TER    JC101387
# 984   False  0815    048XX S KOMENSKY AVE    JC102348
# 985   False  0734    069XX S ELIZABETH ST    JC101408
# 986   False  1114      003XX N PULASKI RD    JC102858
# 987   False  0423  092XX S COMMERCIAL AVE    JC176644
# 988   False  2422       017XX W HOWARD ST    JC101402
# 989   False  0834  078XX S KILPATRICK AVE    JC102741
# 990   False  1132    039XX W LEXINGTON ST    JC101420
# 991   False  1632       033XX N NAGLE AVE    JC102029
# 992   False  2512       021XX N SAYRE AVE    JC102169
# 993   False  0121        002XX S CANAL ST    JC102803
# 994   False  1422   033XX W EVERGREEN AVE    JC112731
# 995   False  0614         086XX S WOOD ST    JC118914
# 996   False  0623     076XX S PRAIRIE AVE    JC144656
# 997   False  0735         071XX S WOOD ST    JC101429
# 998   False  0232         001XX E 60TH ST    JC101403
# 999   False  1235      020XX S ALLPORT ST    JC107623
#
#                         date  \
# 0    2019-01-01T00:00:00.000
# 1    2019-01-01T00:00:00.000
# 2    2019-01-01T00:00:00.000
# 3    2019-01-01T00:00:00.000
# 4    2019-01-01T00:00:00.000
# 5    2019-01-01T00:00:00.000
# 6    2019-01-01T00:00:00.000
# 7    2019-01-01T00:00:00.000
# 8    2019-01-01T00:00:00.000
# 9    2019-01-01T00:00:00.000
# 10   2019-01-01T00:00:00.000
# 11   2019-01-01T00:00:00.000
# 12   2019-01-01T00:00:00.000
# 13   2019-01-01T00:00:00.000
# 14   2019-01-01T00:00:00.000
# 15   2019-01-01T00:00:00.000
# 16   2019-01-01T00:00:00.000
# 17   2019-01-01T00:00:00.000
# 18   2019-01-01T00:00:00.000
# 19   2019-01-01T00:00:00.000
# 20   2019-01-01T00:00:00.000
# 21   2019-01-01T00:00:00.000
# 22   2019-01-01T00:00:00.000
# 23   2019-01-01T00:00:00.000
# 24   2019-01-01T00:00:00.000
# 25   2019-01-01T00:00:00.000
# 26   2019-01-01T00:00:00.000
# 27   2019-01-01T00:00:00.000
# 28   2019-01-01T00:00:00.000
# 29   2019-01-01T00:00:00.000
# ..                       ...
# 970  2019-01-02T04:48:00.000
# 971  2019-01-02T04:50:00.000
# 972  2019-01-02T04:58:00.000
# 973  2019-01-02T05:00:00.000
# 974  2019-01-02T05:00:00.000
# 975  2019-01-02T05:00:00.000
# 976  2019-01-02T05:22:00.000
# 977  2019-01-02T05:30:00.000
# 978  2019-01-02T05:30:00.000
# 979  2019-01-02T05:41:00.000
# 980  2019-01-02T05:50:00.000
# 981  2019-01-02T05:50:00.000
# 982  2019-01-02T06:00:00.000
# 983  2019-01-02T06:00:00.000
# 984  2019-01-02T06:00:00.000
# 985  2019-01-02T06:00:00.000
# 986  2019-01-02T06:00:00.000
# 987  2019-01-02T06:00:00.000
# 988  2019-01-02T06:42:00.000
# 989  2019-01-02T06:45:00.000
# 990  2019-01-02T07:00:00.000
# 991  2019-01-02T07:00:00.000
# 992  2019-01-02T07:00:00.000
# 993  2019-01-02T07:00:00.000
# 994  2019-01-02T07:00:00.000
# 995  2019-01-02T07:00:00.000
# 996  2019-01-02T07:00:00.000
# 997  2019-01-02T07:05:00.000
# 998  2019-01-02T07:10:00.000
# 999  2019-01-02T07:16:00.000
#
#                                            description district  domestic  \
# 0                                           AUTOMOBILE      016     False
# 1                        SEX ASSLT OF CHILD BY FAM MBR      007      True
# 2                                           AUTOMOBILE      016     False
# 3                              THEFT OF LABOR/SERVICES      005     False
# 4                       SEXUAL EXPLOITATION OF A CHILD      005     False
# 5                                        FROM BUILDING      018     False
# 6                                           AUTOMOBILE      022     False
# 7                              DOMESTIC BATTERY SIMPLE      009      True
# 8                                          TO PROPERTY      007     False
# 9                                        FROM BUILDING      018     False
# 10                                          TO VEHICLE      025     False
# 11                                      NON-AGGRAVATED      019     False
# 12                                         TO PROPERTY      025     False
# 13                      HARASSMENT BY ELECTRONIC MEANS      004     False
# 14                                       FROM BUILDING      018     False
# 15                                      $500 AND UNDER      003     False
# 16                                         CHILD ABUSE      017     False
# 17                             HARASSMENT BY TELEPHONE      002      True
# 18                               STRONGARM - NO WEAPON      003      True
# 19                 FINANCIAL IDENTITY THEFT OVER $ 300      015     False
# 20                                      COMPUTER FRAUD      018     False
# 21                 FINANCIAL IDENTITY THEFT OVER $ 300      019     False
# 22                                          AUTOMOBILE      010     False
# 23                                   CREDIT CARD FRAUD      011     False
# 24   NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IM...      004     False
# 25                                         TO PROPERTY      008     False
# 26                          OTHER CRIME AGAINST PERSON      008     False
# 27                 FINANCIAL IDENTITY THEFT OVER $ 300      020     False
# 28             FINANCIAL IDENTITY THEFT $300 AND UNDER      019     False
# 29                 FINANCIAL IDENTITY THEFT OVER $ 300      019     False
# ..                                                 ...      ...       ...
# 970  AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET S...      004      True
# 971                                  AGGRAVATED: OTHER      002     False
# 972                      AGGRAVATED: OTHER DANG WEAPON      012     False
# 973                            DOMESTIC BATTERY SIMPLE      006      True
# 974                                     $500 AND UNDER      020     False
# 975                                     FORCIBLE ENTRY      004     False
# 976                            DOMESTIC BATTERY SIMPLE      005      True
# 977                                          OVER $500      001     False
# 978                                     $500 AND UNDER      007     False
# 979                                             SIMPLE      019     False
# 980                            DOMESTIC BATTERY SIMPLE      024      True
# 981                      AGGRAVATED: OTHER DANG WEAPON      011      True
# 982                                     $500 AND UNDER      008     False
# 983                                             SIMPLE      024      True
# 984                                         AUTOMOBILE      008     False
# 985                            DOMESTIC BATTERY SIMPLE      007      True
# 986                                             SIMPLE      011     False
# 987                FINANCIAL IDENTITY THEFT OVER $ 300      004     False
# 988                                       RETAIL THEFT      024     False
# 989                                       TO RESIDENCE      008     False
# 990                                      FROM BUILDING      011     False
# 991                                         TO VEHICLE      016     False
# 992                                     FORCIBLE ENTRY      025     False
# 993                                     $500 AND UNDER      001     False
# 994                        VIOLATE ORDER OF PROTECTION      014      True
# 995                                     $500 AND UNDER      006     False
# 996                                         AUTOMOBILE      006     False
# 997                            DOMESTIC BATTERY SIMPLE      007      True
# 998                                     ARMED: HANDGUN      002     False
# 999                     HARASSMENT BY ELECTRONIC MEANS      012     False
#
#     fbi_code             location_description                primary_type ward
# 0         07   PARKING LOT/GARAGE(NON.RESID.)         MOTOR VEHICLE THEFT   41
# 1         02                        RESIDENCE  OFFENSE INVOLVING CHILDREN    6
# 2         07   PARKING LOT/GARAGE(NON.RESID.)         MOTOR VEHICLE THEFT   41
# 3         11                        APARTMENT          DECEPTIVE PRACTICE   34
# 4         17                        RESIDENCE                 SEX OFFENSE   34
# 5         06                       RESTAURANT                       THEFT   42
# 6         07                           STREET         MOTOR VEHICLE THEFT   21
# 7        08B                        APARTMENT                     BATTERY   15
# 8         14                        APARTMENT             CRIMINAL DAMAGE   16
# 9         06                       RESTAURANT                       THEFT    2
# 10        14                 RESIDENCE-GARAGE             CRIMINAL DAMAGE   36
# 11        02                            OTHER         CRIM SEXUAL ASSAULT   46
# 12        14                            OTHER             CRIMINAL DAMAGE   36
# 13        26                        RESIDENCE               OTHER OFFENSE    7
# 14        06                    BAR OR TAVERN                       THEFT   42
# 15        06                           STREET                       THEFT    5
# 16        20                        APARTMENT  OFFENSE INVOLVING CHILDREN   33
# 17        26                        APARTMENT               OTHER OFFENSE    4
# 18        03                        APARTMENT                     ROBBERY    7
# 19        11                        RESIDENCE          DECEPTIVE PRACTICE   28
# 20        11                        RESIDENCE          DECEPTIVE PRACTICE   43
# 21        11                            OTHER          DECEPTIVE PRACTICE   47
# 22        07    RESIDENTIAL YARD (FRONT/BACK)         MOTOR VEHICLE THEFT   24
# 23        11                            OTHER          DECEPTIVE PRACTICE   27
# 24        17                        RESIDENCE                 SEX OFFENSE    7
# 25        14                        RESIDENCE             CRIMINAL DAMAGE   14
# 26        26                        RESIDENCE               OTHER OFFENSE   13
# 27        11                        APARTMENT          DECEPTIVE PRACTICE   40
# 28        11                            OTHER          DECEPTIVE PRACTICE   32
# 29        11                        APARTMENT          DECEPTIVE PRACTICE   46
# ..       ...                              ...                         ...  ...
# 970      04B                        APARTMENT                     BATTERY   10
# 971       02                        APARTMENT         CRIM SEXUAL ASSAULT    4
# 972      04B                           STREET                     BATTERY   25
# 973      08B                        APARTMENT                     BATTERY   17
# 974       06                           STREET                       THEFT   47
# 975       05                        RESIDENCE                    BURGLARY    8
# 976      08B                        RESIDENCE                     BATTERY    9
# 977       06                           STREET                       THEFT   42
# 978       06                           STREET                       THEFT   15
# 979      08A                        CTA TRAIN                     ASSAULT   44
# 980      08B                        APARTMENT                     BATTERY   40
# 981      04A                        APARTMENT                     ASSAULT   24
# 982       06                           STREET                       THEFT   17
# 983      08B                        APARTMENT                     BATTERY   49
# 984       07                           STREET         MOTOR VEHICLE THEFT   14
# 985      08B                        RESIDENCE                     BATTERY    6
# 986      08A      CTA GARAGE / OTHER PROPERTY                     ASSAULT   28
# 987       11                             BANK          DECEPTIVE PRACTICE   10
# 988       06               GROCERY FOOD STORE                       THEFT   49
# 989       26                        RESIDENCE           CRIMINAL TRESPASS   18
# 990       06                        APARTMENT                       THEFT   24
# 991       14                           STREET             CRIMINAL DAMAGE   36
# 992       05                        RESIDENCE                    BURGLARY   29
# 993       06  OTHER COMMERCIAL TRANSPORTATION                       THEFT   42
# 994       26                        RESIDENCE               OTHER OFFENSE   26
# 995       06   PARKING LOT/GARAGE(NON.RESID.)                       THEFT   21
# 996       07                           STREET         MOTOR VEHICLE THEFT    6
# 997      08B                        RESIDENCE                     BATTERY   17
# 998       03                         SIDEWALK                     ROBBERY   20
# 999       26                            OTHER               OTHER OFFENSE   25
#
# [1000 rows x 12 columns]

# %%
curl http://localhost:5000/data -d "city=SFO" -d "start_time=2019-01-01T00:00:00=" -d "end_time=2019-01-10T00:00:00" POST -v
